# %%
# !pip3.5
# Out:
# Usage:
#   pip3.5 <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# ...

# %%
import sys
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=5, micro=2, releaselevel='final', serial=0)

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.0MB 385kB/s eta 0:00:01    |█                               | 296kB 2.2MB/s eta 0:00:05     |██████████▉                     | 3.4MB 2.6MB/s eta 0:00:03     |███████████▊                    | 3.7MB 2.6MB/s eta 0:00:03     |█████████████                   | 4.1MB 2.6MB/s eta 0:00:03     |██████████████▊                 | 4.6MB 2.6MB/s eta 0:00:03     |████████████████▌               | 5.2MB 2.6MB/s eta 0:00:02     |█████████████████▉              | 5.6MB 2.8MB/s eta 0:00:02     |███████████████████▌            | 6.1MB 2.8MB/s eta 0:00:02     |████████████████████▍           | 6.4MB 2.8MB/s eta 0:00:02     |█████████████████████▋          | 6.8MB 2.8MB/s eta 0:00:02     |███████████████████████████▍    | 8.6MB 2.6MB/s eta 0:00:01
# ...

# %%
pip install --user pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/74/24/0cdbf8907e1e3bc5a8da03345c23cbed7044330bb8f73bb12e711a640a00/pandas-0.24.2-cp35-cp35m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/eb/ec/d4b7855249ce87ece79783562dd6101b1f0abf461c25101c2e959d691e68/numpy-1.18.0-cp35-cp35m-manylinux1_x86_64.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import io
import

# %%
dt = open("bookings.csv")
dt.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-fd0ca1b1c0c7> in <module>
#       1 dt = open("bookings.csv")
# ----> 2 dt.head()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'head'

# %%
f_in = open("bookings.csv.bz2", "rb")
f_in
# Out:
# <_io.BufferedReader name='bookings.csv.bz2'>

# %%
f_out = open("bookings.csv.bz2", "wb")
f_out.write(bz2.decompress(f_in.read()))
# Out:
# 0

# %%
# !cat matplotlib
# Out:
# cat: matplotlib: No existe el archivo o el directorio

# %% [markdown]
# Clase de Challenge 10 enero 2020 - IGOR:
#
# En Big Data nunca se trabaja con todos los datos. Tener el mismo formato.

# %%
ls -l
# Out:
# total 2027864
# -rw-rw-r-- 1 raquelsl raquelsl  554970628 nov 24 05:09 bookings.csv.bz2
# -rw-rw-r-- 1 raquelsl raquelsl          0 ene 10 22:34 bookings.sample.csv
# -rw-rw-r-- 1 raquelsl raquelsl      25293 ene 10 22:35 Challenge Project.ipynb
# -rw-rw-r-- 1 raquelsl raquelsl 1038318333 ene 10 22:19 drive-download-20200111T081247Z-001.zip
# -rw-rw-r-- 1 raquelsl raquelsl  483188920 nov 24 05:12 searches.csv.bz2
# -rw-rw-r-- 1 raquelsl raquelsl         72 ene 10 22:38 Untitled1.ipynb
# -rw-rw-r-- 1 raquelsl raquelsl       1330 ene  5 18:49 Untitled.ipynb

# %%
# %automagic #es the python
# Out:
# Automagic is OFF, % prefix IS needed for line magics.

# %%
import bz2

# %%
# !bzcat bookings.csv.bz2 | head 10 #cogeme el archivo bookings y presentame las 10 lineas
# Out:
# head: no se puede abrir '10' para lectura: No existe el archivo o el directorio
#
# bzcat: I/O or other error, bailing out.  Possible reason follows.
# bzcat: Broken pipe
# 	Input file = bookings.csv.bz2, output file = (stdout)

# %%
! bzcat bookings.csv.bz2 | head -10000 > bookings.sample.csv #guardamelo en un fichero
# Out:
# bzcat: I/O or other error, bailing out.  Possible reason follows.
# bzcat: Broken pipe
# 	Input file = bookings.csv.bz2, output file = (stdout)

# %%
# !bzip2 -f bookings.sample.csv

# %%
fileBz2 = bz2.BZ2File('./bookings.sample.csv.bz2')
type(fileBz2)
# Out:
# bz2.BZ2File

# %%
### ---------------------------------------

# %%
try:
    with bz2.BZ2File('./bookings.sample.csv.bz2') as fileBz2:
        for k, line in enumerate(fileBz2):
            pass
    print(k+1)
        
except FileNotFoundError as mess1:
    print(mess1)
    
except ValueError:
    print("Value error")
    
except:
    print("Unexpected error")
# Out:
# 10000

# %%
fileBz2.closed
# Out:
# True

# %% [markdown]
# Top 10 arrival airports in the world 2013:

# %%
import pandas as pd

# %%
b = pd.read_csv('bookings.csv.bz2', sep='^')

# %%
b = pd.read_csv('bookings.sample.csv.bz2', sep='^', nrows=9999)

# %%
b.shape
# Out:
# (9999, 38)

# %%
list(b.columns)
# Out:
# ['act_date           ',
#  'source',
#  'pos_ctry',
#  'pos_iata',
#  'pos_oid  ',
#  'rloc          ',
#  'cre_date           ',
#  'duration',
#  'distance',
#  'dep_port',
#  'dep_city',
#  'dep_ctry',
#  'arr_port',
#  'arr_city',
#  'arr_ctry',
#  'lst_port',
#  'lst_city',
#  'lst_ctry',
#  'brd_port',
#  'brd_city',
#  'brd_ctry',
#  'off_port',
#  'off_city',
#  'off_ctry',
#  'mkt_port',
#  'mkt_city',
#  'mkt_ctry',
#  'intl',
#  'route          ',
#  'carrier',
#  'bkg_class',
#  'cab_class',
#  'brd_time           ',
#  'off_time           ',
#  'pax',
#  'year',
#  'month',
#  'oid      ']

# %%
b.sample(5) #toma muestras de manera aleatoria
# Out:
#       act_date             source  pos_ctry                          pos_iata  \
# 5282  2013-03-14 00:00:00  1S      CA        96ac3a7c13c9d34e39c11f9989c654da
# 2306  2013-03-11 00:00:00  1V      US        21e082fc77186038a4259ef15f61a60e
# 555   2013-03-14 00:00:00  1A      SY        fed776207e7d178767345ade006aef3d
# 2105  2013-03-30 00:00:00  1A      US        bc99142aac9b034b8223c2d4bce52b69
# 3803  2013-03-02 00:00:00  1S      IT        7b7dbb6f049f0691ca645b45932c89e4
#
#                              pos_oid                      rloc            \
# 5282  3906e13efcda3332a3b208d7172b803a  24050219a7f0ceeb2936ded0638cee47
# 2306  8f25f20bc6c0b832fa5234eb10d0c181  9da66ba52e6264919a8f71eef2625032
# 555   4ea7d262d211fd64dacb5c6ca848ce7a  3b4defc90f1d2fbf79e204314a9175f9
# 2105  773b68b2beae1a7a21010d50233b98f2  9d3a2a2e177bf7c45182acec1006d790
# 3803  4b355d4f966fcecd80b6df7a46924356  58287365967d183987ca9288caf621e1
#
# ...

# %%
pd.set_option('display.max_columns', None) #¿para que sirve?

# %%
b.sample(5) #es una base de datos que viene un gds(aerolineas-agencia)
# Out:
#       act_date             source  pos_ctry                          pos_iata  \
# 6287  2013-03-04 00:00:00  1V      CA        5b4a13bd5eeadfcb1496eb665b95b1e1
# 7653  2013-03-13 00:00:00  1P      US        4804033f441ee30d92980c8b2207e8ae
# 2153  2013-03-12 00:00:00  1A      IT        dc5a69e18e050de9c898d8b3c04773dd
# 2801  2013-03-29 00:00:00  1V      US        b175c22cd5c38d236873d3df80b5d83d
# 1105  2013-03-12 00:00:00  1A      FR        cfa8b068139cbbe6796b66cc534d54b8
#
#                              pos_oid                      rloc            \
# 6287  8fd097c47035bde39ecda30f454f2ee5  1bdf112c3782fc38a21b8d8cfd08fd4a
# 7653  4868da7a1666bbbc5fe33d377690f8eb  5508dd93b8933c924eb92c82c94621e4
# 2153  caa2b87bc7776f054854ceb87307fa40  777b7067c79173f9b8ae2e58c8398223
# 2801  ab3f315b2a26bf88bcb16f2a171c66dd  5b0c9d150f1e8f36dacc8848d3111d41
# 1105  cbcb97d56272bd41481bef9f75c07962  e26af3ed30dcb3d9c14f593ed61ea95a
#
# ...

# %% [markdown]
# codigo iata lo que esta cacheado(encriptado) y codigo oid la pantalla negra de la agencia
#
# rloc es tu reserva
#
# creation date y activated day: se utiliza para obtener un historial
#
# duration: para ver el tipo de viajero que eres
#
# distance: 0 ida y vuelta
#
# mark port: join la ida
#
# mark city:
#
# inti: si es o no internacional
#
# route: la ruta de por donde pasa y sus paradas
#
# booking class: cuanto hemos pagado
#
# cab: el espacio/fisico que tenemos dentro del avion (business/economy/)
#
# brd time:  tiempo de la hora
#
# off time:
#
# pax: numero de pasajeros
#
# year:
#
# month:
#
# oid:

# %% [markdown]
# Commands for obtaining data info:

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 38 columns):
# act_date               9999 non-null object
# source                 9999 non-null object
# pos_ctry               9999 non-null object
# pos_iata               9999 non-null object
# pos_oid                9999 non-null object
# rloc                   9999 non-null object
# cre_date               9999 non-null object
# duration               9999 non-null int64
# distance               9999 non-null int64
# dep_port               9999 non-null object
# dep_city               9999 non-null object
# dep_ctry               9999 non-null object
# arr_port               9999 non-null object
# arr_city               9999 non-null object
# arr_ctry               9999 non-null object
# lst_port               9999 non-null object
# lst_city               9999 non-null object
# lst_ctry               9999 non-null object
# brd_port               9999 non-null object
# ...

# %%
b.describe()
# Out:
#             duration      distance         intl          pax    year   month
# count    9999.000000   9999.000000  9999.000000  9999.000000  9999.0  9999.0
# mean    20209.746075    455.608861     0.596260     0.516152  2013.0     3.0
# std     42243.233482   1738.891068     0.490671     1.783970     0.0     0.0
# min        59.000000      0.000000     0.000000   -25.000000  2013.0     3.0
# 25%      3339.000000      0.000000     0.000000    -1.000000  2013.0     3.0
# 50%      7721.000000      0.000000     1.000000     1.000000  2013.0     3.0
# 75%     19077.000000      0.000000     1.000000     1.000000  2013.0     3.0
# max    488131.000000  18481.000000     1.000000    25.000000  2013.0     3.0

# %%
b.groupby('rloc          ')['act_date           '].count().sort_values(ascending=False).head(10)
# Out:
# rloc
# ae15bcfc5aec0eb64b2c5204d08201d5    42
# fb72a3899ed1cd353c5830388935e7f5    23
# cd96f7b7fdb5743769053ba273c7eb5f    20
# 6b7878dd4ac59772e14ab4760ab45ad0    20
# 68aee71ee0f40aff44ed341f2c5f8627    16
# 2a86eac3e29c922f4a439fbc0480985b    15
# 58ee9c6852513816a39363a1621a0615    14
# 503d8dde8034a48c262b3f5764fc60ca    14
# c9f19404e4f0755c40deaebd6e90ea84    13
# 182485c12b7e38aa6e2d24f7484c019b    12
# Name: act_date           , dtype: int64

# %% [markdown]
# Esta reserva tiene 42 dos cambios, la siguiente 23, la siguiente 20

# %%
b[b['rloc          '] == 'ae15bcfc5aec0eb64b2c5204d08201d5'    ].sort_values('act_date           ', ascending=True)
# Out:
#       act_date             source  pos_ctry                          pos_iata  \
# 7745  2013-03-01 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7746  2013-03-01 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7747  2013-03-01 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7748  2013-03-01 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7749  2013-03-02 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7750  2013-03-02 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7751  2013-03-04 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7752  2013-03-04 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7756  2013-03-07 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7755  2013-03-07 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# 7753  2013-03-07 00:00:00  1P      ZA        9782cc0d8e04d24e7346699ea97d5f90
# ...

# %% [markdown]
# No coincide el creation day con el activite day, puede ser que no tengamos todo el historia.

# %% [markdown]
# 2) Select the columns of interest

# %%
# arr_port, pax, year

# %% [markdown]
# 3) What to do whit NaN?

# %%
#Drop

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
b = pd.read_csv('bookings.sample.csv.bz2', sep='^', usecols=['arr_port', 'pax', 'year'], nrows=9999)
b = b.dropna()

#con esto conseguimos una tabla con nuestras tres columnas

# %%
len(b)
# Out:
# 9999

# %% [markdown]
# Plan:
#
#     1) filtrar 2013
#
#     2) group by arr_port
#
#     3) sum sobre pax
#
#     4) ordenar sobre sum de pax
#
#     5) top 100

# %%
filter=b[b['year'] == 2013]

# %%
filter.groupby(['arr_port'])['pax'].sum().sort_values(ascending=False)
# Out:
# arr_port
# HKG         112
# LGA          95
# ORD          94
# JFK          92
# SFO          91
# LAX          91
# MCO          90
# DCA          82
# DEN          79
# LHR          76
# LAS          70
# ATL          69
# PHX          69
# DFW          67
# FLL          64
# SEA          61
# BWI          55
# IAD          49
# PVG          49
# FCO          47
# MEX          46
# BCN          46
# BOS          46
# EWR          46
# IST          44
# PHL          41
# MIA          38
# AMS          36
# ATH          36
# DTW          35
#            ...
# ITM          -2
# RUN          -2
# UBP          -2
# EYW          -2
# CUR          -2
# LED          -2
# TOS          -2
# LAO          -2
# EZS          -2
# OVB          -2
# MLX          -3
# BGA          -3
# RIC          -3
# ZAG          -4
# MDZ          -4
# GAU          -4
# NGB          -4
# OGG          -4
# RFP          -4
# MAA          -5
# MAO          -6
# STS          -6
# AYT          -6
# ABZ          -6
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
b = pd.read_csv('bookings.sample.csv.bz2', sep='^', usecols=['arr_port', 'pax', 'year'], nrows=9999)
b = b.dropna()
b = b[b['year']==2013]
del b['year']
b.groupby(['arr_port']).sum().sort_values('pax', ascending=False).head()
# Out:
#           pax
# arr_port
# HKG       112
# LGA        95
# ORD        94
# JFK        92
# LAX        91

# %%
import pandas as pd
import bz2

# %%
bi = pd.read_csv('bookings.csv.bz2',sep='^', usecols=["arr_port'. 'pax', 'year'], nrows=9999, iterator=True)
# Out:
#   File "<ipython-input-76-df1948db657e>", line 1
#     bi = pd.read_csv('bookings.csv.bz2', sep='^', usecols=["arr_port'. 'pax', 'year'], nrows=9999, iterator=True)
#                                                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
bi = pd.read_csv('bookings.csv.bz2',sep='^', usecols=['arr_port', 'pax', 'year'], nrows=9999, iterator=True)

# %%
type(bi)
# Out:
# pandas.io.parsers.TextFileReader

# %%
bi = pd.read_csv('bookings.csv.bz2',sep='^', usecols=['arr_port', 'pax', 'year'], nrows=9999, iterator=True, chunksize=3000)

# %%
type(bi)
# Out:
# pandas.io.parsers.TextFileReader

# %%
for i, b in enumerate(bi):
    print(len(b))
# Out:
# 3000
# 3000
# 3000
# 999

# %%
b = b.dropna()
b = b[b['year']==2013]
del b['year']
b.groupby(['arr_port']).sum()

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

bi = pd.read_csv('bookings.csv.bz2', sep='^', usecols=['arr_port', 'pax', 'year'], nrows=9999, chunksize=3000)

all_chunks = pd.DataFrame()

for i, b in enumerate(bi):
    print(i,len(b))
    b = b.dropna()
    b = b[b['year']==2013]
    del b['year']
    results=b.groupby(['arr_port']).sum()
    
    all_chunks = all_chunks.append(results)

result_all = all_chunks.reset_index().groupby(['arr_port']).sum().sort_values('pax', ascending=False).reset_index()
result_all.head(10)
# Out:
# 0 3000
# 1 3000
# 2 3000
# 3 999
#    arr_port  pax
# 0  HKG       112
# 1  LGA        95
# 2  ORD        94
# 3  JFK        92
# 4  LAX        91
# 5  SFO        91
# 6  MCO        90
# 7  DCA        82
# 8  DEN        79
# 9  LHR        76

# %%
all_chunks.reset_index().shape
# Out:
# (1344, 2)

# %%
all_chunks.reset_index()
# Out:
#       arr_port  pax
# 0     ABQ         2
# 1     ACC         0
# 2     ADD         4
# 3     AEP         3
# 4     AER         1
# 5     AES         2
# 6     AGA         0
# 7     AGP         8
# 8     AJF         0
# 9     AKL         1
# 10    ALA         6
# 11    ALB         2
# 12    ALC         4
# 13    ALG        12
# 14    AMD         1
# 15    AMM         3
# 16    AMS        15
# 17    ANC         2
# 18    ARH         1
# 19    ARN         4
# 20    ASE         0
# 21    ASU       -10
# 22    ASW         2
# 23    ATH        12
# 24    ATL        19
# 25    ATQ         1
# 26    AUH         1
# 27    AUS         1
# 28    AVL         2
# 29    AXM         0
# ...        ...  ...
# 1314  SJO         2
# 1315  SJU         0
# 1316  SLC         2
# 1317  SSH         1
# 1318  STL         1
# 1319  STT         2
# 1320  SVO         0
# 1321  SYD         0
# 1322  TFS         6
# 1323  TLH         2
# 1324  TLV         0
# 1325  TPE        11
# 1326  TRD         2
# ...

# %%
# %%time
import pandas as pd
pd.set_option('display.max_columns', None)

bi = pd.read_csv('bookings.csv.bz2', sep='^', usecols=['arr_port', 'pax', 'year'], chunksize=1000000)

all_chunks = pd.DataFrame()

for i, b in enumerate(bi):
    print(i,len(b))
    b = b.dropna()
    b = b[b['year']==2013]
    del b['year']
    results=b.groupby(['arr_port']).sum()
    
    all_chunks = all_chunks.append(results)

result_all = all_chunks.reset_index().groupby(['arr_port']).sum().sort_values('pax', ascending=False).reset_index()
result_all.head(10)
# Out:
# 0 1000000
# 1 1000000
# 2 1000000
# 3 1000000
# 4 1000000
# 5 1000000
# 6 1000000
# 7 1000000
# 8 1000000
# 9 1000000
# 10 10
# CPU times: user 3min 36s, sys: 448 ms, total: 3min 37s
# Wall time: 3min 58s
#    arr_port      pax
# 0  LHR       88809.0
# 1  MCO       70930.0
# 2  LAX       70530.0
# 3  LAS       69630.0
# 4  JFK       66270.0
# 5  CDG       64490.0
# 6  BKK       59460.0
# 7  MIA       58150.0
# 8  SFO       58000.0
# 9  DXB       55590.0

# %%
result_all.head(10)
# Out:
#    arr_port      pax
# 0  LHR       88809.0
# 1  MCO       70930.0
# 2  LAX       70530.0
# 3  LAS       69630.0
# 4  JFK       66270.0
# 5  CDG       64490.0
# 6  BKK       59460.0
# 7  MIA       58150.0
# 8  SFO       58000.0
# 9  DXB       55590.0

# %%
result_all.shape
# Out:
# (2274, 2)

# %%
# %automagic
# Out:
# Automagic is OFF, % prefix IS needed for line magics.

# %%
# %pip install --user neobase
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/d8/f2/0ca4a5818f8271f7c6d59bb336c28db931e22b51330947983be86ba4ea12/NeoBase-0.20.2.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# ...
#     Running setup.py install for neobase ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import neobase as nb

# %%
dir(nb) #para ver que cosas hay
# Out:
# ['LatLng',
#  'NeoBase',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'neobase']

# %%
help(nb)
# Out:
# Help on package neobase:
#
# NAME
#     neobase - # -*- coding: utf-8 -*-
#
# PACKAGE CONTENTS
#     __main__
#     neobase
#
# FILE
#     /home/raquelsl/.local/lib/python3.5/site-packages/neobase/__init__.py

# %%
from neobase import NeoBase

# %%
dir(NeoBase)
# Out:
# ['DUPLICATES',
#  'FIELDS',
#  'KEY',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_distances',
#  '_empty_value',
#  'distance',
#  'distance_between_locations',
#  'find_closest_from_location',
#  'find_near',
#  'find_near_location',
#  'find_with',
#  'get',
#  'get_location',
#  'keys',
#  'load',
#  'set',
#  'skip']

# %%
help(NeoBase)
# Out:
# Help on class NeoBase in module neobase.neobase:
#
# class NeoBase(builtins.object)
#  |  Main structure, a wrapper around a dict, with dict-like behavior.
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key)
#  |      Test if a key is in the base.
#  |
#  |      :param key: the key of to be tested
#  |      :returns:   a boolean
#  |
#  |      >>> b = NeoBase()
#  |      >>> 'AN' in b
#  |      False
#  |      >>> 'AGN' in b
#  |      True
#  |
#  |  __init__(self, rows=None, date=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Returns iterator of all keys in the base.
#  |
#  |      :returns: the iterator of all keys
#  |
#  |      >>> b = NeoBase()
#  |      >>> sorted(b)
#  |      ['AAA', 'AAA@1', 'AAB', ...
#  |
#  |  __len__(self)
#  |      Testing structure size.
#  |
#  |      :returns: a integer
#  |
#  |      >>> b = NeoBase()
#  |      >>> 18000 < len(b) < 20000
#  |      True
#  |
# ...

# %%
geoDict = NeoBase() #ha inicializado

# %%
type(geoDict)
# Out:
# neobase.neobase.NeoBase

# %%
geoDict.get('LHR') #el diccionario me devuelve los valores que tiene para ese aeropuerto
# Out:
# {'__dup__': set(),
#  'city_code_list': ['LON'],
#  'city_name_list': ['London'],
#  'continent_name': 'Europe',
#  'country_code': 'GB',
#  'country_name': 'United Kingdom',
#  'currency': 'GBP',
#  'iata_code': 'LHR',
#  'lat': '51.4775',
#  'lng': '-0.461389',
#  'location_type': ['A'],
#  'name': 'London Heathrow Airport',
#  'page_rank': 0.44517643489228376,
#  'timezone': 'Europe/London'}

# %%
geoDict.get('LHR')['name']
# Out:
# 'London Heathrow Airport'

# %%
result_all.head(3)
# Out:
#    arr_port      pax
# 0  LHR       88809.0
# 1  MCO       70930.0
# 2  LAX       70530.0

# %%
result_all['arr_port'] = result_all['arr_port'].str.strip() 
#he quitado todos los espacios de todos los elementos del dataframe

# %%
result_all.arr_port[0]
# Out:
# 'LHR'

# %%
geoDict.get(result_all.arr_port[0])['name']
# Out:
# 'London Heathrow Airport'

# %%
result_all['AirportName'] = result_all['arr_port'].map(lambda x: geoDict.get(x)['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/neobase/neobase.py in get(self, key, field, default)
#     227         try:
# --> 228             d = self._data[key]
#     229         except KeyError:
#
# KeyError: 'CPQ'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-b86960c7551c> in <module>
# ----> 1 result_all['AirportName'] = result_all['arr_port'].map(lambda x: geoDict.get(x)['name'])
#
# ~/.local/lib/python3.5/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
# ...

# %%
print(len(result_all))
result_all = result_all[ result_all['arr_port'] != 'CPQ']
print(len(result_all))
# Out:
# 2274
# 2273

# %%
result_all['AirportName'] = result_all['arr_port'].map(lambda x: geoDict.get(x)['name'])
result_all.head(10)
# Out:
#   arr_port      pax                            AirportName
# 0      LHR  88809.0                London Heathrow Airport
# 1      MCO  70930.0          Orlando International Airport
# 2      LAX  70530.0      Los Angeles International Airport
# 3      LAS  69630.0         McCarran International Airport
# 4      JFK  66270.0  John F. Kennedy International Airport
# 5      CDG  64490.0        Paris Charles de Gaulle Airport
# 6      BKK  59460.0                   Suvarnabhumi Airport
# 7      MIA  58150.0            Miami International Airport
# 8      SFO  58000.0    San Francisco International Airport
# 9      DXB  55590.0            Dubai International Airport

# %%
result_all = result_all.astype({'pax': int})

# %%
result_all.head()
# Out:
#   arr_port    pax                            AirportName
# 0      LHR  88809                London Heathrow Airport
# 1      MCO  70930          Orlando International Airport
# 2      LAX  70530      Los Angeles International Airport
# 3      LAS  69630         McCarran International Airport
# 4      JFK  66270  John F. Kennedy International Airport

# %%
result_all.to_csv('top_airports.csv', sep='^', index=False)

# %%
ls -l
# Out:
# total 2028636
# -rw-rw-r-- 1 raquelsl raquelsl  554970628 nov 24 05:09 bookings.csv.bz2
# -rw-rw-r-- 1 raquelsl raquelsl     535893 ene 10  2020 bookings.sample.csv.bz2
# -rw-rw-r-- 1 raquelsl raquelsl     199286 ene 10 13:53 Challenge Project.ipynb
# -rw-rw-r-- 1 raquelsl raquelsl 1038318333 ene 10  2020 drive-download-20200111T081247Z-001.zip
# -rw-rw-r-- 1 raquelsl raquelsl  483188920 nov 24 05:12 searches.csv.bz2
# -rw-rw-r-- 1 raquelsl raquelsl      77878 ene 10 13:54 top_airports.csv
# -rw-rw-r-- 1 raquelsl raquelsl         72 ene 10  2020 Untitled1.ipynb
# -rw-rw-r-- 1 raquelsl raquelsl       1330 ene  5 18:49 Untitled.ipynb

# %%
! head top_airports.csv
# Out:
# arr_port^pax^AirportName
# LHR^88809^London Heathrow Airport
# MCO^70930^Orlando International Airport
# LAX^70530^Los Angeles International Airport
# LAS^69630^McCarran International Airport
# JFK^66270^John F. Kennedy International Airport
# CDG^64490^Paris Charles de Gaulle Airport
# BKK^59460^Suvarnabhumi Airport
# MIA^58150^Miami International Airport
# SFO^58000^San Francisco International Airport

# %% [markdown]
# Write a Web Service

# %%
import json

# %%
list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %%
json.dumps(list("abcd")) #como se ve en formato json
# Out:
# '["a", "b", "c", "d"]'

# %%
myDict={'name':'Hey', 'age': 31, 'city': "Madrid"}

# %%
myDict
# Out:
# {'age': 31, 'city': 'Madrid', 'name': 'Hey'}

# %%
json.dumps(myDict) #se que es un diccionario
# Out:
# '{"age": 31, "name": "Hey", "city": "Madrid"}'

# %% [markdown]
# Vamos a crear dos diccionarios con el objetivo de crear un dataframe para posteriormente visualizarlo

# %%
myDict2={'name':['Hey', 'Holi'], 'age':[31, 45], 'city':['Madrid', 'New York']}
myDict2
# Out:
# {'age': [31, 45], 'city': ['Madrid', 'New York'], 'name': ['Hey', 'Holi']}

# %%
import pandas as pd

# %%
df_from_dict = pd.DataFrame.from_dict(myDict2)

# %%
df_from_dict
# Out:
#    age      city  name
# 0   31    Madrid   Hey
# 1   45  New York  Holi

# %%
df_from_dict.to_json()
# Out:
# '{"age":{"0":31,"1":45},"city":{"0":"Madrid","1":"New York"},"name":{"0":"Hey","1":"Holi"}}'

# %%
df_from_dict = pd.DataFrame.from_dict(myDict2, orient = 'index')

#el elemento 0 tiene un diccionario y el elemnto 1 tiene otro
df_from_dict
# Out:
#            0         1
# age       31        45
# name     Hey      Holi
# city  Madrid  New York

# %% [markdown]
# Me llega texto en json y se si es una lista, un diccionario, un valor.
#
# Utilizo el texto y creo algo.
#
# Json mandar la información en formato de texto

# %%
ls
# Out:
# bookings.csv.bz2                         searches.csv.bz2
# bookings.sample.csv.bz2                  top_airports.csv
# Challenge Project.ipynb                  Untitled1.ipynb
# drive-download-20200111T081247Z-001.zip  Untitled.ipynb

# %%
df = pd.read_csv('top_airports.csv', sep='^')
df
# Out:
#      arr_port    pax                                        AirportName
# 0         LHR  88809                            London Heathrow Airport
# 1         MCO  70930                      Orlando International Airport
# 2         LAX  70530                  Los Angeles International Airport
# 3         LAS  69630                     McCarran International Airport
# 4         JFK  66270              John F. Kennedy International Airport
# 5         CDG  64490                    Paris Charles de Gaulle Airport
# 6         BKK  59460                               Suvarnabhumi Airport
# 7         MIA  58150                        Miami International Airport
# 8         SFO  58000                San Francisco International Airport
# 9         DXB  55590                        Dubai International Airport
# 10        ORD  53200               Chicago O'Hare International Airport
# 11        FCO  45120                Leonardo da Vinci–Fiumicino Airport
# ...

# %%
df.head(5)
# Out:
#   arr_port    pax                            AirportName
# 0      LHR  88809                London Heathrow Airport
# 1      MCO  70930          Orlando International Airport
# 2      LAX  70530      Los Angeles International Airport
# 3      LAS  69630         McCarran International Airport
# 4      JFK  66270  John F. Kennedy International Airport

# %%
df.head(5).to_json() #cojo el dataframe los primeros 5 y el texto.
# Out:
# '{"arr_port":{"0":"LHR","1":"MCO","2":"LAX","3":"LAS","4":"JFK"},"pax":{"0":88809,"1":70930,"2":70530,"3":69630,"4":66270},"AirportName":{"0":"London Heathrow Airport","1":"Orlando International Airport","2":"Los Angeles International Airport","3":"McCarran International Airport","4":"John F. Kennedy International Airport"}}'

# %% [markdown]
# Hay unas paginas webs puedes ver si el texto es validado o no.
#
# Si es valido en formato json
