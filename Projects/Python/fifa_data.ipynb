# %%
#First all, we are importing the libraries
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
! unzip -l fifa-20-complete-player-dataset.zip #decompress the archive
# Out:
# Archive:  fifa-20-complete-player-dataset.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#   7537167  2019-09-26 20:19   players_15.csv
#   7922126  2019-09-26 20:19   players_16.csv
#   8450801  2019-09-26 20:19   players_17.csv
#   8862980  2019-09-26 20:19   players_18.csv
#   8832562  2019-09-26 20:19   players_19.csv
#   8945067  2019-09-26 20:19   players_20.csv
#     32382  2019-09-26 20:19   teams_and_leagues.csv
# ---------                     -------
#  50583085                     7 files

# %%
# decompress the archive 
import zipfile
zipfilename = 'fifa-20-complete-player-dataset.zip'
password = None
#open and extract all files in the zip

zf = zipfile.ZipFile(zipfilename, "r")
try:
    z.extractall(pwd=password)
except:
    print("Error")
    pass
zf.close()

# %%
players19 = pd.read_csv("players_19.csv", encoding = 'utf-8', sep = ',')
players19.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
players18 = pd.read_csv("players_18.csv", encoding = 'utf-8', sep =',')
players18.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   25  1992-02-05
# 3           M. Neuer                         Manuel Neuer   31  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   30  1987-01-24
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
players18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17592 entries, 0 to 17591
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.0+ MB

# %%
players19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.1+ MB

# %%
players19.shape
# Out:
# (17770, 104)

# %%
players19.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
# Take a something variable like name, age, height, weight, nationality and club
data = players19[['short_name', 'age', 'height_cm', 'weight_kg','nationality','club']]
data.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0  Cristiano Ronaldo   33        187         83    Portugal
# 1           L. Messi   31        170         72   Argentina
# 2          Neymar Jr   26        175         68      Brazil
# 3             De Gea   27        193         76       Spain
# 4       K. De Bruyne   27        181         70     Belgium
#
#                   club
# 0             Juventus
# 1         FC Barcelona
# 2  Paris Saint-Germain
# 3    Manchester United
# 4      Manchester City

# %%
data[['age']].max() # this is the old player
# Out:
# age    45
# dtype: int64

# %%
data.loc[data['age'].max(),['short_name', 'nationality', 'club']] #his name is Lukaku and play in Manchester United
# Out:
# short_name             R. Lukaku
# nationality              Belgium
# club           Manchester United
# Name: 45, dtype: object

# %%
data[data['club'] == 'FC Barcelona'].count() # Count all vble about FC Barcelona club
# Out:
# short_name     28
# age            28
# height_cm      28
# weight_kg      28
# nationality    28
# club           28
# dtype: int64

# %%
age_over = data[data['age'] > 25 ]
age_down = data[data['age'] < 25 ]

# %%
table_age = pd.concat([age_over,age_down], keys=['age_over', 'age_down'])
table_age
# Out:
#                           short_name  age  height_cm  weight_kg  \
# age_over 0         Cristiano Ronaldo   33        187         83
#          1                  L. Messi   31        170         72
#          2                 Neymar Jr   26        175         68
#          3                    De Gea   27        193         76
#          4              K. De Bruyne   27        181         70
#          5              Sergio Ramos   32        184         82
#          6                 L. Suárez   31        182         86
#          7                 L. Modrić   32        172         66
#          8                 E. Hazard   27        173         74
#          10              T. Courtois   26        199         96
#          11                 M. Neuer   32        193         92
#          12                 D. Godín   32        187         78
#          13                 T. Kroos   28        183         76
#          14           R. Lewandowski   29        184         80
# ...

# %%
#def team_age(club):
    #age = []
 #   team = []
 #   for i in team:
 #       i = i+1

# %%
team = data['club'].unique()
team
# Out:
# array(['Juventus', 'FC Barcelona', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Real Madrid', 'Chelsea',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Inter', 'Milan', 'Napoli', 'Arsenal', 'Lazio',
#        'FC Schalke 04', 'Valencia CF', 'Olympique Lyonnais', 'Roma',
#        'LA Galaxy', 'Beşiktaş JK', 'AS Monaco', 'FC Porto',
#        'Guangzhou Evergrande Taobao FC', 'Borussia Dortmund', 'RC Celta',
#        'Olympique de Marseille', 'Real Betis', 'Villarreal CF',
#        'Atalanta', 'Leicester City', 'AS Saint-Étienne', 'SL Benfica',
#        'Real Sociedad', 'Bayer 04 Leverkusen', '1. FC Köln', 'RB Leipzig',
#        'Sporting CP', 'Everton', 'Dalian YiFang FC',
#        'TSG 1899 Hoffenheim', 'Sevilla FC', 'Athletic Club de Bilbao',
#        'Wolverhampton Wanderers', 'Al Nassr', 'OGC Nice',
#        'Atlético Mineiro', 'Grêmio', 'Torino', 'Ajax', 'VfL Wolfsburg',
# ...

# %%
team_player = data.groupby('club')['short_name'].count() #the number of player per club
team_player
# Out:
# club
#  SSV Jahn Regensburg        29
# 1. FC Heidenheim 1846       28
# 1. FC Kaiserslautern        25
# 1. FC Köln                  28
# 1. FC Magdeburg             26
# 1. FC Nürnberg              28
# 1. FC Union Berlin          28
# 1. FSV Mainz 05             32
# AC Ajaccio                  22
# AC Horsens                  25
# AD Alcorcón                 29
# ADO Den Haag                28
# AEK Athens                  28
# AFC Wimbledon               26
# AIK                         27
# AJ Auxerre                  27
# AS Béziers                  27
# AS Monaco                   33
# AS Nancy Lorraine           29
# AS Saint-Étienne            26
# AZ Alkmaar                  30
# Aalborg BK                  27
# Aarhus GF                   27
# Aberdeen                    27
# Accrington Stanley          28
# Adelaide United             24
# Ajax                        29
# Akhisar Belediyespor        26
# Al Ahli                     30
# Al Batin                    29
# ...

# %%
colum = ['short_name', 'long_name', 'age', 'dob',
       'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
       'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
       'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
       'body_type', 'real_face', 'release_clause_eur', 'player_tags',
       'team_position', 'team_jersey_number', 'loaned_from', 'joined',
       'contract_valid_until', 'nation_position', 'nation_jersey_number',
       'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
       'gk_positioning', 'player_traits', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes']

# %%
play19 = players19[colum] # we create a new variable with 76 columns and 17770 observation
play19.shape
# Out:
# (17770, 76)

# %%
play19.describe() #obtain the summary of vbles
# Out:
#                 age     height_cm     weight_kg       overall     potential  \
# count  17770.000000  17770.000000  17770.000000  17770.000000  17770.000000
# mean      25.193922    181.253292     75.310917     66.240405     71.382949
# std        4.651957      6.745892      7.080013      6.994104      6.145171
# min       16.000000    154.000000     50.000000     47.000000     48.000000
# 25%       21.000000    176.000000     70.000000     62.000000     67.000000
# 50%       25.000000    181.000000     75.000000     66.000000     71.000000
# 75%       28.000000    186.000000     80.000000     71.000000     75.000000
# max       45.000000    205.000000    110.000000     94.000000     95.000000
#
#           value_eur       wage_eur  international_reputation     weak_foot  \
# count  1.777000e+04   17770.000000              17770.000000  17770.000000
# mean   2.440756e+06    9956.162071                  1.117783      2.946427
# ...

# %%
play19.head()
# Out:
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        187         83    Portugal             Juventus       94         94
# 1        170         72   Argentina         FC Barcelona       94         94
# 2        175         68      Brazil  Paris Saint-Germain       92         93
# 3        193         76       Spain    Manchester United       91         93
# 4        181         70     Belgium      Manchester City       91         92
#
# ...

# %%
play19.columns
# Out:
# Index(['short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
#        'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'player_positions', 'preferred_foot', 'international_reputation',
#        'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until',
#        'nation_position', 'nation_jersey_number', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
# ...

# %%
columns_play  = ['goalkeeping_positioning','short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
       'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur',
       'player_positions', 'preferred_foot', 'international_reputation',
       'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face',
       'release_clause_eur', 'player_tags', 'team_position',
       'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until',
       'nation_position', 'nation_jersey_number', 'pace', 'shooting',
       'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
       'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
       'gk_positioning', 'player_traits', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking']

# %%
play19[columns_play]
# Out:
#       goalkeeping_positioning            short_name  \
# 0                          14     Cristiano Ronaldo
# 1                          14              L. Messi
# 2                          15             Neymar Jr
# 3                          88                De Gea
# 4                          10          K. De Bruyne
# 5                           7          Sergio Ramos
# 6                          33             L. Suárez
# 7                          14             L. Modrić
# 8                           8             E. Hazard
# 9                          88              J. Oblak
# 10                         87           T. Courtois
# 11                         88              M. Neuer
# 12                          5              D. Godín
# 13                          7              T. Kroos
# 14                          8        R. Lewandowski
# 15                          5             P. Dybala
# 16                         85         M. ter Stegen
# ...

# %%
def club (x): # funcion for team 
    return play19[play19['club'] == x][['short_name', 'long_name', 'age',
       'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
       'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
       'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
       'body_type', 'real_face', 'release_clause_eur', 'player_tags',
       'team_position', 'team_jersey_number', 'loaned_from', 'joined',
       'contract_valid_until', 'nation_position', 'nation_jersey_number',
       'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
       'gk_positioning', 'player_traits', 'attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes']]

# %%
club('Real Madrid')
# Out:
#             short_name                          long_name  age  height_cm  \
# 5         Sergio Ramos                Sergio Ramos García   32        184
# 7            L. Modrić                        Luka Modrić   32        172
# 10         T. Courtois                   Thibaut Courtois   26        199
# 13            T. Kroos                         Toni Kroos   28        183
# 17                Isco     Francisco Román Alarcón Suárez   26        176
# 28            Casemiro  Carlos Henrique Venancio Casimiro   26        185
# 37             G. Bale                  Gareth Frank Bale   28        185
# 38             Marcelo     Marcelo Vieira da Silva Júnior   30        174
# 55            K. Navas                       Keylor Navas   31        185
# 57           R. Varane                     Raphaël Varane   25        191
# 78       Marco Asensio            Marco Asensio Willemsen   22        182
# 120           Carvajal              Daniel Carvajal Ramos   26        173
# ...

# %%
club('Real Madrid').describe()
# Out:
#              age   height_cm  weight_kg    overall  potential     value_eur  \
# count  33.000000   33.000000  33.000000  33.000000  33.000000  3.300000e+01
# mean   24.030303  181.212121  75.636364  77.848485  84.727273  2.666894e+07
# std     4.524136    5.925356   6.618243  10.383645   5.827053  2.579895e+07
# min    17.000000  172.000000  66.000000  63.000000  72.000000  4.250000e+05
# 25%    20.000000  178.000000  70.000000  64.000000  80.000000  1.000000e+06
# 50%    23.000000  182.000000  76.000000  80.000000  86.000000  1.850000e+07
# 75%    28.000000  184.000000  80.000000  87.000000  90.000000  5.100000e+07
# max    32.000000  199.000000  96.000000  91.000000  93.000000  8.300000e+07
#
#             wage_eur  international_reputation  weak_foot  skill_moves  ...  \
# count      33.000000                 33.000000  33.000000    33.000000  ...
# mean   150333.333333                  2.090909   3.272727     2.818182  ...
# ...

# %%
club('FC Barcelona').describe()
# Out:
#             age   height_cm  weight_kg    overall  potential     value_eur  \
# count  28.00000   28.000000  28.000000  28.000000  28.000000  2.800000e+01
# mean   24.75000  179.750000  74.357143  80.285714  86.142857  2.992589e+07
# std     4.55115    6.812978   5.920550   8.330476   4.608481  2.701647e+07
# min    18.00000  169.000000  66.000000  63.000000  75.000000  5.250000e+05
# 25%    21.00000  174.750000  69.000000  76.000000  83.000000  4.950000e+06
# 50%    24.00000  180.000000  73.500000  82.000000  87.000000  2.800000e+07
# 75%    29.00000  184.250000  78.000000  87.000000  89.250000  4.000000e+07
# max    32.00000  194.000000  86.000000  94.000000  94.000000  1.105000e+08
#
#             wage_eur  international_reputation  weak_foot  skill_moves  ...  \
# count      28.000000                 28.000000  28.000000    28.000000  ...
# mean   169535.714286                  2.464286   3.321429     2.964286  ...
# ...

# %%
club('Real Madrid').corr()
# Out:
#                                age  height_cm  weight_kg   overall  potential  \
# age                       1.000000   0.143138   0.440817  0.801690   0.473298
# height_cm                 0.143138   1.000000   0.744720  0.148848   0.040646
# weight_kg                 0.440817   0.744720   1.000000  0.493014   0.321477
# overall                   0.801690   0.148848   0.493014  1.000000   0.871626
# potential                 0.473298   0.040646   0.321477  0.871626   1.000000
# value_eur                 0.654216   0.133973   0.439310  0.880122   0.822357
# wage_eur                  0.830701   0.056371   0.395602  0.920972   0.766927
# international_reputation  0.827912   0.206774   0.529128  0.830524   0.642405
# weak_foot                 0.184532  -0.336155  -0.178932  0.227655   0.200891
# skill_moves               0.057517  -0.582201  -0.339064  0.278636   0.424895
# release_clause_eur        0.627392   0.138658   0.439159  0.877944   0.840160
# ...

# %%
sns.heatmap(real_madrid.corr(), linewidths=.1)
