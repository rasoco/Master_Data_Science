# %% [markdown]
# # Loading CSV

# %%
import pandas as pd

# %%
# !dir
# Out:
#  El volumen de la unidad C es OS
#  El número de serie del volumen es: F0CD-7350
#
#  Directorio de C:\Users\rsoco\Desktop\MASTER_DATA_SCIENCE\Master
#
# 13/12/2019  21:29    <DIR>          .
# 13/12/2019  21:29    <DIR>          ..
# 13/12/2019  21:23    <DIR>          .ipynb_checkpoints
# 13/12/2019  08:22           321.978 01_intro_to_DS_toolkit_halfempty.ipynb
# 13/12/2019  21:29             9.842 02-loading_and_saving_data_empty.ipynb
# 13/12/2019  08:22             5.420 03-merge_concatenate_transform_empty.ipynb
# 13/12/2019  08:22             3.243 04-group_by_empty.ipynb
# 13/12/2019  08:22            23.399 05-visualization_introduction_empty.ipynb
# 09/12/2019  18:16    <DIR>          Git and Github
# 13/12/2019  08:22             1.709 houses.csv
# 08/12/2019  11:24    <DIR>          Python
# 13/12/2019  08:22            61.194 train.csv
#                7 archivos        426.785 bytes
#                5 dirs  848.868.241.408 bytes libres

# %% [markdown]
# # Saving to Excel

# %%
# !dir
# Out:
#  El volumen de la unidad C es OS
#  El número de serie del volumen es: F0CD-7350
#
#  Directorio de C:\Users\rsoco\Desktop\MASTER_DATA_SCIENCE\Master
#
# 13/12/2019  21:31    <DIR>          .
# 13/12/2019  21:31    <DIR>          ..
# 13/12/2019  21:23    <DIR>          .ipynb_checkpoints
# 13/12/2019  08:22           321.978 01_intro_to_DS_toolkit_halfempty.ipynb
# 13/12/2019  21:31             4.850 02-loading_and_saving_data_empty.ipynb
# 13/12/2019  08:22             5.420 03-merge_concatenate_transform_empty.ipynb
# 13/12/2019  08:22             3.243 04-group_by_empty.ipynb
# 13/12/2019  08:22            23.399 05-visualization_introduction_empty.ipynb
# 09/12/2019  18:16    <DIR>          Git and Github
# 13/12/2019  08:22             1.709 houses.csv
# 08/12/2019  11:24    <DIR>          Python
# 13/12/2019  08:22            61.194 train.csv
#                7 archivos        421.793 bytes
#                5 dirs  848.871.170.048 bytes libres

# %%
df = pd.read_csv("../AccidentesBicicletas_2019.csv", encoding = 'latin1', sep=';')
df
# Out:
#     Nº  EXPEDIENTE       FECHA   HORA  \
# 0      2019S000659  01/01/2019  14:00
# 1      2019S000036  02/01/2019  20:45
# 2      2019S000133  03/01/2019  14:30
# 3      2019S000132  03/01/2019  12:45
# 4      2019S000132  03/01/2019  12:45
# 5      2019S000045  03/01/2019  10:30
# 6      2019S000306  04/01/2019  17:10
# 7      2019S000641  04/01/2019  13:35
# 8      2019S000904  07/01/2019  14:00
# 9      2019S002373  08/01/2019  20:55
# 10     2019S002373  08/01/2019  20:55
# 11     2019S001738  08/01/2019  13:03
# 12     2019S001943  09/01/2019  14:50
# 13     2019S001678  09/01/2019  12:50
# 14     2019S002882  10/01/2019  20:30
# 15     2019S003283  11/01/2019  16:00
# 16     2019S002594  12/01/2019  22:45
# 16   POLIG. ALUCHE-AVENIDA DE LOS POBLADOS / CALL. ...      -
# 17          CALL. GENERAL RICARDOS / GTA. VALLE DE ORO      -
# 18                       AVDA. POBLADOS / CALL. SECOYA      -
# 19                          AVDA. ENSANCHE DE VALLECAS     44
# 20                                   CALL. SANCHIDRIAN    13A
# 21   CALL. MIGUEL ANGEL / PASEO. GENERAL MARTINEZ C...      -
# 22                                     PASEO. EL PARDO     37
# 23      CALL. SANTA GENOVEVA / PLAZA. AGUSTIN GONZALEZ      -
# 24                                         CALL. FLORA      1
# 25                    PLAZA. CONDE DEL VALLE DE SUCHIL      3
# 26               AVDA. DAROCA / CALL. NICOLAS SALMERON      -
# 27                        CALL. ARENAL / CALL. DONADOS      -
# 28                                       CALL. SERRANO    141
# 29                               CALL. DOCE DE OCTUBRE     26
# ..                                                 ...    ...
# 749                  TRVA. SAN MATEO / CALL. HORTALEZA      -
# 750                                       CALL. ORENSE     18
# 751   AVDA. CANILLEJAS A VICALVARO / CALL. SANTA TECLA      -
# 752               CALL. ANTONIA CALVO / CALL. ALHAMBRA      -
# 753            CALL. O'DONNELL / AVDA. MENENDEZ PELAYO      -
# 754            CALL. O'DONNELL / AVDA. MENENDEZ PELAYO      -
# 755                                CALL. BRAVO MURILLO    155
# 756                                   CALL. FUENCARRAL    134
# 757                                CALL. BRAVO MURILLO    120
# 758                                       PASEO. PRADO     14
# 759             PLAZA. CRONOS / CALL. INOCENTA DE MESA      -
# 760          CALL. JUANITA CRUZ / CALL. GLORIA FUERTES      -
# 761                  AVDA. POBLADOS / CALL. CERILLERAS      -
# 762  CALL. FERNANDEZ DE LA HOZ / CALL. GENERAL ARRANDO      -
# 763  CALL. FERNANDEZ DE LA HOZ / CALL. GENERAL ARRANDO      -
# 764              CALL. ALCALA / CALL. MARQUES DE CUBAS      -
# 765   AVDA. CANILLEJAS A VICALVARO / CALL. SANTA TECLA      -
# 766    CALL. DIEGO DE LEON / CALL. PRINCIPE DE VERGARA      -
# 767                                 CALL. ELOY GONZALO     33
# 768  AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 769                               CALL. LOPEZ DE HOYOS     66
# 770                                       CALL. ALCALA   200A
# 771             PLAZA. ALONSO MARTINEZ / CALL. SAGASTA      -
# 772             PLAZA. ALONSO MARTINEZ / CALL. SAGASTA      -
# 773                              AVDA. MENENDEZ PELAYO     65
# 774                                 CALL. ARTURO SORIA   334A
# 775               CALL. SAN CONRADO / AVDA. MANZANARES      -
# 776                     RONDA. SEGOVIA / CALL. SEGOVIA      -
# 777                                       PASEO. PRADO     40
# 778                                  CALL. EMBAJADORES    172
#
#                 DISTRITO                TIPO ACCIDENTE ESTADO METEREOLÓGICO  \
# 0              SALAMANCA                       Alcance            Despejado
# 1              HORTALEZA       Colisión fronto-lateral            Despejado
# 2      VILLA DE VALLECAS                       Alcance         Se desconoce
# 3      VILLA DE VALLECAS                       Alcance            Despejado
# 4      VILLA DE VALLECAS                       Alcance            Despejado
# 5        MONCLOA-ARAVACA                         Caída            Despejado
# 6              CHAMARTÍN       Colisión fronto-lateral            Despejado
# 7              MORATALAZ       Colisión fronto-lateral            Despejado
# 8    FUENCARRAL-EL PARDO       Colisión fronto-lateral            Despejado
# 9             ARGANZUELA           Atropello a persona            Despejado
# 10            ARGANZUELA           Atropello a persona            Despejado
# 11   FUENCARRAL-EL PARDO                         Caída            Despejado
# 12           CARABANCHEL              Colisión lateral            Despejado
# 13                CENTRO                       Alcance            Despejado
# 14            ARGANZUELA                         Caída            Despejado
# 15                CENTRO       Colisión fronto-lateral            Despejado
# 16                LATINA  Choque contra obstáculo fijo            Despejado
# 17           CARABANCHEL       Colisión fronto-lateral            Despejado
# 18           CARABANCHEL  Choque contra obstáculo fijo            Despejado
# 19     VILLA DE VALLECAS       Colisión fronto-lateral         Se desconoce
# 20                LATINA                       Alcance            Despejado
# 21              CHAMBERÍ       Colisión fronto-lateral                  NaN
# 22   FUENCARRAL-EL PARDO                         Caída            Despejado
# 23         CIUDAD LINEAL              Colisión lateral            Despejado
# 24                CENTRO                         Caída            Despejado
# 25              CHAMBERÍ                         Caída            Despejado
# 26         CIUDAD LINEAL       Colisión fronto-lateral            Despejado
# 27                CENTRO              Colisión lateral            Despejado
# 28             CHAMARTÍN                       Alcance            Despejado
# 29                RETIRO  Choque contra obstáculo fijo            Despejado
# ..                   ...                           ...                  ...
# 749               CENTRO       Colisión fronto-lateral              Nublado
# 750               TETUÁN                       Alcance         Lluvia débil
# 751  SAN BLAS-CANILLEJAS                         Caída              Nublado
# 752               LATINA              Colisión lateral            Despejado
# 753               RETIRO           Atropello a persona            Despejado
# 754               RETIRO           Atropello a persona            Despejado
# 755               TETUÁN              Colisión lateral            Despejado
# 756             CHAMBERÍ       Colisión fronto-lateral         Lluvia débil
# 757               TETUÁN                       Alcance         Lluvia débil
# 758               CENTRO                       Alcance         Lluvia débil
# 759  SAN BLAS-CANILLEJAS       Colisión fronto-lateral         Lluvia débil
# 760  FUENCARRAL-EL PARDO                         Caída            Despejado
# 761          CARABANCHEL       Colisión fronto-lateral            Despejado
# 762             CHAMBERÍ                         Caída         Lluvia débil
# 763             CHAMBERÍ                         Caída         Lluvia débil
# 764               CENTRO                         Caída            Despejado
# 765  SAN BLAS-CANILLEJAS                         Caída            Despejado
# 766            SALAMANCA       Colisión fronto-lateral            Despejado
# 767             CHAMBERÍ                         Caída            Despejado
# 768               RETIRO                         Caída            Despejado
# 769            CHAMARTÍN                         Caída            Despejado
# 770            SALAMANCA                         Caída              Nublado
# 771             CHAMBERÍ           Atropello a persona            Despejado
# 772             CHAMBERÍ           Atropello a persona            Despejado
# 773               RETIRO                         Caída            Despejado
# 774        CIUDAD LINEAL                         Caída            Despejado
# 775               LATINA       Colisión fronto-lateral            Despejado
# 776               CENTRO                       Alcance            Despejado
# 753     Bicicleta    Conductor  DE 18 A 20 AÑOS   Mujer        14.0
# 754     Bicicleta       Peatón  DE 45 A 49 AÑOS  Hombre         7.0
# 755     Bicicleta    Conductor  DE 25 A 29 AÑOS   Mujer        14.0
# 756     Bicicleta    Conductor  DE 60 A 64 AÑOS  Hombre         7.0
# 757     Bicicleta    Conductor  DE 30 A 34 AÑOS   Mujer         1.0
# 758     Bicicleta    Conductor      DESCONOCIDA     NaN         NaN
# 759     Bicicleta    Conductor  DE 60 A 64 AÑOS  Hombre         7.0
# 760     Bicicleta    Conductor  DE 55 A 59 AÑOS  Hombre         6.0
# 761     Bicicleta    Conductor    DE 0 A 5 AÑOS  Hombre         7.0
# 762     Bicicleta    Conductor  DE 18 A 20 AÑOS  Hombre        14.0
# 763     Bicicleta       Peatón  DE 70 A 74 AÑOS   Mujer         7.0
# 764     Bicicleta    Conductor  DE 35 A 39 AÑOS  Hombre         6.0
# 765     Bicicleta    Conductor  DE 50 A 54 AÑOS  Hombre         6.0
# 766     Bicicleta    Conductor  DE 25 A 29 AÑOS  Hombre         5.0
# 767     Bicicleta    Conductor  DE 30 A 34 AÑOS  Hombre         2.0
# 768     Bicicleta    Conductor  DE 30 A 34 AÑOS  Hombre         1.0
# 769     Bicicleta    Conductor      DESCONOCIDA     NaN         NaN
# 770     Bicicleta    Conductor  DE 55 A 59 AÑOS  Hombre         6.0
# 771     Bicicleta    Conductor      DESCONOCIDA  Hombre         NaN
# 772     Bicicleta       Peatón  DE 35 A 39 AÑOS  Hombre         7.0
# 773     Bicicleta    Conductor  DE 21 A 24 AÑOS  Hombre         3.0
# 774     Bicicleta    Conductor  DE 40 A 44 AÑOS  Hombre         7.0
# 775     Bicicleta    Conductor  DE 25 A 29 AÑOS  Hombre         NaN
# 776     Bicicleta    Conductor  DE 50 A 54 AÑOS   Mujer         7.0
# 777     Bicicleta    Conductor  DE 21 A 24 AÑOS  Hombre         2.0
# 778     Bicicleta    Conductor  DE 21 A 24 AÑOS  Hombre         1.0
#
# [779 rows x 13 columns]

# %% [markdown]
# # Saving to CSV

# %%
df.to_excel('data/results.xls')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-dee8b72c4399> in <module>()
# ----> 1 df.to_excel('data/results.xls')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     652                            freeze_panes=freeze_panes)
#     653         if need_save:
# --> 654             writer.save()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1460         Save workbook to disk.
#    1461         """
# -> 1462         return self.book.save(self.path)
#    1463
#    1464     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlwt\Workbook.py in save(self, filename_or_stream)
#     708
#     709         doc = CompoundDoc.XlsDoc()
# --> 710         doc.save(filename_or_stream, self.get_biff_data())
#     711
#     712
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlwt\CompoundDoc.py in save(self, file_name_or_filelike_obj, stream)
#     260         we_own_it = not hasattr(f, 'write')
#     261         if we_own_it:
# --> 262             f = open(file_name_or_filelike_obj, 'w+b')
#     263         f.write(self.header)
#     264         f.write(self.packed_MSAT_1st)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/results.xls'

# %%
df.to_csv('data')

# %%
# !dir
# Out:
#  El volumen de la unidad C es OS
#  El número de serie del volumen es: F0CD-7350
#
#  Directorio de C:\Users\rsoco\Desktop\MASTER_DATA_SCIENCE\Master
#
# 13/12/2019  21:43    <DIR>          .
# 13/12/2019  21:43    <DIR>          ..
# 13/12/2019  21:23    <DIR>          .ipynb_checkpoints
# 13/12/2019  08:22           321.978 01_intro_to_DS_toolkit_halfempty.ipynb
# 13/12/2019  21:43            66.692 02-loading_and_saving_data_empty.ipynb
# 13/12/2019  08:22             5.420 03-merge_concatenate_transform_empty.ipynb
# 13/12/2019  08:22             3.243 04-group_by_empty.ipynb
# 13/12/2019  08:22            23.399 05-visualization_introduction_empty.ipynb
# 09/12/2019  18:16    <DIR>          Git and Github
# 13/12/2019  08:22             1.709 houses.csv
# 08/12/2019  11:24    <DIR>          Python
# 13/12/2019  08:22            61.194 train.csv
#                7 archivos        483.635 bytes
#                5 dirs  848.864.796.672 bytes libres

# %% [markdown]
# # Reading Excel

# %%
pd.read_excel("../01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls", sheet_name = '2010', skiprows=7, index_col=0, usecols= "A:K", skipfooter= 1)
# Out:
#                                 COLISIÓN DOBLE                            \
# DISTRITO_ACCIDENTE
# ARGANZUELA                                                           403
# BARAJAS                                                               62
# CARABANCHEL                                                          357
# CENTRO                                                               546
# CHAMARTIN                                                            460
# CHAMBERI                                                             361
# CIUDAD LINEAL                                                        404
# FUENCARRAL-EL PARDO                                                  294
# HORTALEZA                                                            183
# LATINA                                                               273
# MONCLOA-ARAVACA                                                      350
# MORATALAZ                                                            127
# PUENTE DE VALLECAS                                                   324
# RETIRO                                                               349
# SALAMANCA                                                            506
# SAN BLAS                                                             274
# TETUAN                                                               331
# USERA                                                                178
# VICALVARO                                                             65
# VILLA DE VALLECAS                                                    124
# VILLAVERDE                                                           147
#
#                                 COLISIÓN MÚLTIPLE                         \
# DISTRITO_ACCIDENTE
# ARGANZUELA                                                            48
# BARAJAS                                                                5
# CARABANCHEL                                                           35
# CENTRO                                                                43
# CHAMARTIN                                                             67
# CHAMBERI                                                              34
# CIUDAD LINEAL                                                         79
# FUENCARRAL-EL PARDO                                                   49
# HORTALEZA                                                             15
# LATINA                                                                37
# MONCLOA-ARAVACA                                                       47
# MORATALAZ                                                             21
# PUENTE DE VALLECAS                                                    44
# RETIRO                                                                55
# PUENTE DE VALLECAS                                                   7.0
# RETIRO                                                               5.0
# SALAMANCA                                                            6.0
# SAN BLAS                                                             2.0
# TETUAN                                                               3.0
# USERA                                                                4.0
# VICALVARO                                                            5.0
# VILLA DE VALLECAS                                                    3.0
# VILLAVERDE                                                           1.0

# %%
#skiprows elimina columnas que no te interesa

# %%
#skifooter elimina ultima columna

# %% [markdown]
# #### Exercise
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.
#
# COGETE TODAS LAS HOJAS, HACER UNA TABLA LARGA

# %% [markdown]
# # To Sql Database

# %%
import sqlite3 # lo ha utilizado dos veces
connection = sqlite3.connect('newdb.db')

# %%
df.to_sql('mynewtable', con=connection, if_exists='replace')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %% [markdown]
# # To dictionary and to json

# %%
 df.head().to_dict() #es util
# Out:
# {'Nº  EXPEDIENTE': {0: '2019S000659',
#   1: '2019S000036',
#   2: '2019S000133',
#   3: '2019S000132',
#   4: '2019S000132'},
#  'FECHA': {0: '01/01/2019',
#   1: '02/01/2019',
#   2: '03/01/2019',
#   3: '03/01/2019',
#   4: '03/01/2019'},
#  'HORA': {0: '14:00', 1: '20:45', 2: '14:30', 3: '12:45', 4: '12:45'},
#  'CALLE': {0: 'CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ',
#   1: 'AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES',
#   2: 'CALL. FELIPE ALVAREZ',
#   3: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA',
#   4: 'AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA'},
#  'NÚMERO': {0: '-', 1: '-', 2: '10', 3: '-', 4: '-'},
#  'DISTRITO': {0: 'SALAMANCA',
#   1: 'HORTALEZA',
#   2: 'VILLA DE VALLECAS',
#   3: 'VILLA DE VALLECAS',
#   4: 'VILLA DE VALLECAS'},
#  'TIPO ACCIDENTE': {0: 'Alcance',
#   1: 'Colisión fronto-lateral',
#   2: 'Alcance',
#   3: 'Alcance',
#   4: 'Alcance'},
#  'ESTADO METEREOLÓGICO': {0: 'Despejado',
#   1: 'Despejado',
#   2: 'Se desconoce',
#   3: 'Despejado',
#   4: 'Despejado'},
#  'TIPO VEHÍCULO': {0: 'Bicicleta',
#   1: 'Bicicleta',
#   2: 'Bicicleta',
#   3: 'Bicicleta',
#   4: 'Bicicleta'},
#  'TIPO PERSONA': {0: 'Conductor',
#   1: 'Conductor',
#   2: 'Conductor',
#   3: 'Conductor',
#   4: 'Conductor'},
#  'RANGO DE EDAD': {0: 'DE 25 A 29 AÑOS',
#   1: 'DE 70 A 74 AÑOS',
#   2: 'DE 15 A 17 AÑOS',
#   3: 'DE 18 A 20 AÑOS',
#   4: 'DE 21 A 24 AÑOS'},
#  'SEXO': {0: 'Hombre', 1: 'Hombre', 2: 'Hombre', 3: 'Hombre', 4: 'Hombre'},
#  'LESIVIDAD*': {0: 1.0, 1: 3.0, 2: 7.0, 3: 7.0, 4: 14.0}}

# %%
df.head().to_json()# json lenguaje comparte datos , forma de escribir javascript. xlm es la competencia de json
# Out:
# '{"N\\u00ba  EXPEDIENTE":{"0":"2019S000659","1":"2019S000036","2":"2019S000133","3":"2019S000132","4":"2019S000132"},"FECHA":{"0":"01\\/01\\/2019","1":"02\\/01\\/2019","2":"03\\/01\\/2019","3":"03\\/01\\/2019","4":"03\\/01\\/2019"},"HORA":{"0":"14:00","1":"20:45","2":"14:30","3":"12:45","4":"12:45"},"CALLE":{"0":"CALL. CASTELLO \\/ CALL. DON RAMON DE LA CRUZ","1":"AVDA. GRAN VIA DE HORTALEZA \\/ GTA. LUIS ROSALES","2":"CALL. FELIPE ALVAREZ","3":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA","4":"AVDA. SANTA EUGENIA \\/ CALL. REAL DE ARGANDA"},"N\\u00daMERO":{"0":"-","1":"-","2":"10","3":"-","4":"-"},"DISTRITO":{"0":"SALAMANCA","1":"HORTALEZA","2":"VILLA DE VALLECAS","3":"VILLA DE VALLECAS","4":"VILLA DE VALLECAS"},"TIPO ACCIDENTE":{"0":"Alcance","1":"Colisi\\u00f3n fronto-lateral","2":"Alcance","3":"Alcance","4":"Alcance"},"ESTADO METEREOL\\u00d3GICO":{"0":"Despejado","1":"Despejado","2":"Se desconoce","3":"Despejado","4":"Despejado"},"TIPO VEH\\u00cdCULO":{"0":"Bicicleta","1":"Bicicleta","2":"Bicicleta","3":"Bicicleta","4":"Bicicleta"},"TIPO PERSONA":{"0":"Conductor","1":"Conductor","2":"Conductor","3":"Conductor","4":"Conductor"},"RANGO DE EDAD":{"0":"DE 25 A 29 A\\u00d1OS","1":"DE 70 A 74 A\\u00d1OS","2":"DE 15 A 17 A\\u00d1OS","3":"DE 18 A 20 A\\u00d1OS","4":"DE 21 A 24 A\\u00d1OS"},"SEXO":{"0":"Hombre","1":"Hombre","2":"Hombre","3":"Hombre","4":"Hombre"},"LESIVIDAD*":{"0":1.0,"1":3.0,"2":7.0,"3":7.0,"4":14.0}}'

# %% [markdown]
# # Reading mysql database

# %%
# se usa bastante

# %%
pd.read_sql_query("SELECT FECHA, HORA FROM mynewtable WHERE SEXO = 'Hombre' LIMIT 10", connection)
# Out:
#         FECHA   HORA
# 0  01/01/2019  14:00
# 1  02/01/2019  20:45
# 2  03/01/2019  14:30
# 3  03/01/2019  12:45
# 4  03/01/2019  12:45
# 5  03/01/2019  10:30
# 6  04/01/2019  17:10
# 7  04/01/2019  13:35
# 8  07/01/2019  14:00
# 9  08/01/2019  20:55
